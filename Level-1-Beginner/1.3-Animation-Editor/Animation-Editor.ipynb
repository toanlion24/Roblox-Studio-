# %% [markdown]
# # 🎬 1.3 Animation Editor trong Roblox Studio
#
# ---
#
# ## Mục Tiêu
# > Thành thạo sử dụng Animation Editor để tạo, chỉnh sửa và publish animation trong Roblox Studio.
#
# ---

# %% [markdown]
# # 🛠️ PHẦN 1: SỬ DỤNG ANIMATION EDITOR
#
# ---

# %% [markdown]
# ## 1.1 Mở Animation Editor
#
# ### Cách mở Animation Editor
#
# ```
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                    CÁCH MỞ ANIMATION EDITOR                              │
# ├─────────────────────────────────────────────────────────────────────────┤
# │                                                                         │
# │  BƯỚC 1: Mở Roblox Studio                                               │
# │          └── Mở project hoặc tạo Baseplate mới                          │
# │                                                                         │
# │  BƯỚC 2: Vào tab Avatar                                                 │
# │          ┌─────────────────────────────────────────────────────────┐    │
# │          │ File │ Home │ Model │ Test │ View │ Plugins │ AVATAR │  │    │
# │          └─────────────────────────────────────────────────────────┘    │
# │                                                      ▲                  │
# │                                                      │                  │
# │                                               Click vào đây             │
# │                                                                         │
# │  BƯỚC 3: Click "Animation Editor"                                       │
# │          ┌─────────────────────────────────────────────────────────┐    │
# │          │  Rig Builder  │  Animation Editor  │  Avatar Setup     │    │
# │          └─────────────────────────────────────────────────────────┘    │
# │                                 ▲                                       │
# │                                 │                                       │
# │                          Click vào đây                                  │
# │                                                                         │
# └─────────────────────────────────────────────────────────────────────────┘
# ```
#
# ### Animation Editor Interface
#
# ```
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                    ANIMATION EDITOR INTERFACE                            │
# ├─────────────────────────────────────────────────────────────────────────┤
# │                                                                         │
# │  ┌─────────────────────────────────────────────────────────────────┐    │
# │  │ ◄ ► ⏸ │ Animation Name ▼ │ 0:00 / 1:00 │ ⚙ Settings │ ⋮ Menu │    │
# │  └─────────────────────────────────────────────────────────────────┘    │
# │  │         TOOLBAR (Điều khiển phát, tên animation, settings)      │    │
# │  │                                                                 │    │
# │  ├─────────────────────────────────────────────────────────────────┤    │
# │  │                                                                 │    │
# │  │  TRACK LIST         │          TIMELINE                        │    │
# │  │  ┌───────────────┐  │  0:00    0:05    0:10    0:15    0:20    │    │
# │  │  │ ► HumanoidRoot│  │  │        │        │        │        │   │    │
# │  │  │ ► LowerTorso  │  │  ●────────────────●────────────────●     │    │
# │  │  │ ► UpperTorso  │  │  ●────────●───────────────●──────────    │    │
# │  │  │ ► Head        │  │  ●────────────────────────●──────────    │    │
# │  │  │ ► LeftUpperArm│  │  ●───●────●───●────●──────●──────────    │    │
# │  │  │ ► RightUpperArm│ │  ●───●────●───●────●──────●──────────    │    │
# │  │  │ ► LeftUpperLeg│  │  ●────────────────────────●──────────    │    │
# │  │  │ ► RightUpperLeg│ │  ●────────────────────────●──────────    │    │
# │  │  └───────────────┘  │                                          │    │
# │  │                     │  ● = Keyframe                            │    │
# │  └─────────────────────────────────────────────────────────────────┘    │
# │                                                                         │
# └─────────────────────────────────────────────────────────────────────────┘
# ```
#
# ### Các thành phần chính
#
# | Thành phần | Vị trí | Chức năng |
# |------------|--------|-----------|
# | **Toolbar** | Trên cùng | Play/Pause, chọn animation, settings |
# | **Track List** | Bên trái | Danh sách các body parts |
# | **Timeline** | Bên phải | Hiển thị keyframes theo thời gian |
# | **Playhead** | Timeline | Vạch đỏ hiển thị thời điểm hiện tại |
# | **Menu (⋮)** | Góc phải | Các options như Priority, Looping |

# %% [markdown]
# ## 1.2 Tạo Rig R15
#
# ### Rig là gì?
# **Rig** là character model với đầy đủ cấu trúc xương (bones/joints) để có thể animate. Trước khi tạo animation, bạn cần có một Rig.
#
# ### Cách tạo Rig R15
#
# ```
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                    TẠO RIG R15 BẰNG RIG BUILDER                          │
# ├─────────────────────────────────────────────────────────────────────────┤
# │                                                                         │
# │  BƯỚC 1: Vào tab Avatar                                                 │
# │          └── Avatar → Rig Builder                                       │
# │                                                                         │
# │  BƯỚC 2: Chọn loại Rig                                                  │
# │          ┌─────────────────────────────────────────────────────────┐    │
# │          │               RIG BUILDER POPUP                         │    │
# │          ├─────────────────────────────────────────────────────────┤    │
# │          │                                                         │    │
# │          │   Rig Type:                                             │    │
# │          │   ┌──────────┐  ┌──────────┐                            │    │
# │          │   │    R6    │  │   R15    │  ◄── Chọn R15              │    │
# │          │   └──────────┘  └──────────┘                            │    │
# │          │                                                         │    │
# │          │   Body Type:                                            │    │
# │          │   ○ Block (Blocky avatar)                               │    │
# │          │   ○ Mesh (Realistic avatar)  ◄── Thường dùng            │    │
# │          │   ○ Rthro (Tall proportions)                            │    │
# │          │                                                         │    │
# │          │               [ Create Rig ]                            │    │
# │          └─────────────────────────────────────────────────────────┘    │
# │                                                                         │
# │  BƯỚC 3: Click "Create Rig"                                             │
# │          └── Rig sẽ xuất hiện trong Workspace                           │
# │                                                                         │
# └─────────────────────────────────────────────────────────────────────────┘
# ```
#
# ### Các loại Rig Body Type
#
# | Body Type | Mô tả | Sử dụng khi |
# |-----------|-------|-------------|
# | **Block** | Khối vuông cổ điển Roblox | Game retro, simple style |
# | **Mesh** | Thân hình mượt mà | Game modern, realistic |
# | **Rthro** | Tỉ lệ người thực | Game RPG, realistic |
#
# ### Rig trong Explorer
#
# ```
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                    RIG STRUCTURE TRONG EXPLORER                          │
# ├─────────────────────────────────────────────────────────────────────────┤
# │                                                                         │
# │  Workspace                                                              │
# │  └── Rig (Model)                                                        │
# │      ├── Humanoid                                                       │
# │      │   └── Animator                                                   │
# │      ├── HumanoidRootPart                                               │
# │      ├── Head                                                           │
# │      ├── UpperTorso                                                     │
# │      ├── LowerTorso                                                     │
# │      ├── LeftUpperArm                                                   │
# │      ├── LeftLowerArm                                                   │
# │      ├── LeftHand                                                       │
# │      ├── RightUpperArm                                                  │
# │      ├── RightLowerArm                                                  │
# │      ├── RightHand                                                      │
# │      ├── LeftUpperLeg                                                   │
# │      ├── LeftLowerLeg                                                   │
# │      ├── LeftFoot                                                       │
# │      ├── RightUpperLeg                                                  │
# │      ├── RightLowerLeg                                                  │
# │      └── RightFoot                                                      │
# │                                                                         │
# └─────────────────────────────────────────────────────────────────────────┘
# ```
#
# > 💡 **Tip:** Sau khi tạo Rig, bạn có thể đổi tên nó (ví dụ: "PlayerRig", "EnemyRig") để dễ quản lý.

# %% [markdown]
# ## 1.3 Tạo Animation Mới
#
# ### Các bước tạo Animation mới
#
# ```
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                    TẠO ANIMATION MỚI                                     │
# ├─────────────────────────────────────────────────────────────────────────┤
# │                                                                         │
# │  BƯỚC 1: Chọn Rig trong Workspace                                       │
# │          └── Click vào Rig model bạn vừa tạo                            │
# │                                                                         │
# │  BƯỚC 2: Mở Animation Editor                                            │
# │          └── Avatar → Animation Editor                                  │
# │          └── Popup sẽ hỏi chọn Rig (nếu có nhiều)                       │
# │                                                                         │
# │  BƯỚC 3: Tạo animation mới                                              │
# │          ┌─────────────────────────────────────────────────────────┐    │
# │          │                                                         │    │
# │          │  Click vào tên animation (dropdown) → "Create New"      │    │
# │          │                          HOẶC                           │    │
# │          │  Menu (⋮) → "Create" → "New Animation"                  │    │
# │          │                                                         │    │
# │          └─────────────────────────────────────────────────────────┘    │
# │                                                                         │
# │  BƯỚC 4: Đặt tên animation                                              │
# │          └── Nhập tên (ví dụ: "Walk", "Attack1", "Wave")                │
# │          └── Click "Create"                                             │
# │                                                                         │
# └─────────────────────────────────────────────────────────────────────────┘
# ```
#
# ### Quy tắc đặt tên Animation
#
# | Loại Animation | Ví dụ tên | Ghi chú |
# |----------------|-----------|--------|
# | Movement | `Walk`, `Run`, `Jump`, `Fall` | Dùng động từ |
# | Combat | `Attack1`, `Attack2`, `Block`, `Dodge` | Đánh số combo |
# | Emote | `Wave`, `Dance1`, `Sit`, `Sleep` | Mô tả hành động |
# | Tool | `SwordSlash`, `GunShoot`, `StaffCast` | Tool + Action |
#
# > ⚠️ **Lưu ý:** Tên animation không ảnh hưởng đến script - bạn sẽ dùng Animation ID để load animation.

# %% [markdown]
# ## 1.4 Thêm/Xóa Keyframes
#
# ### Cách thêm Keyframe
#
# ```
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                    THÊM KEYFRAME                                         │
# ├─────────────────────────────────────────────────────────────────────────┤
# │                                                                         │
# │  CÁCH 1: TỰ ĐỘNG (Khuyến nghị)                                          │
# │  ──────────────────────────────                                         │
# │  1. Di chuyển Playhead đến thời điểm muốn thêm keyframe                 │
# │  2. Chọn body part trong Viewport (3D view)                             │
# │  3. Rotate hoặc Move body part                                          │
# │  4. → Keyframe tự động được thêm!                                       │
# │                                                                         │
# │  CÁCH 2: THỦ CÔNG                                                       │
# │  ────────────────                                                       │
# │  1. Di chuyển Playhead đến thời điểm mong muốn                          │
# │  2. Right-click vào track của body part trong Timeline                  │
# │  3. Chọn "Add Keyframe"                                                 │
# │                                                                         │
# │  CÁCH 3: PHÍM TẮT                                                       │
# │  ────────────────                                                       │
# │  1. Chọn body part                                                      │
# │  2. Nhấn K để thêm keyframe tại vị trí Playhead hiện tại                │
# │                                                                         │
# └─────────────────────────────────────────────────────────────────────────┘
# ```
#
# ### Cách xóa Keyframe
#
# ```
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                    XÓA KEYFRAME                                          │
# ├─────────────────────────────────────────────────────────────────────────┤
# │                                                                         │
# │  CÁCH 1: RIGHT-CLICK                                                    │
# │  1. Click vào keyframe (diamond icon) trên Timeline                     │
# │  2. Right-click → "Delete Keyframe"                                     │
# │                                                                         │
# │  CÁCH 2: PHÍM TẮT                                                       │
# │  1. Click chọn keyframe                                                 │
# │  2. Nhấn Delete hoặc Backspace                                          │
# │                                                                         │
# │  CÁCH 3: XÓA NHIỀU KEYFRAMES                                            │
# │  1. Hold Ctrl + Click để chọn nhiều keyframes                           │
# │  2. Hoặc Drag để select vùng                                            │
# │  3. Nhấn Delete                                                         │
# │                                                                         │
# └─────────────────────────────────────────────────────────────────────────┘
# ```
#
# ### Keyframe Operations
#
# | Thao tác | Phím tắt | Mô tả |
# |----------|----------|-------|
# | Thêm Keyframe | `K` | Thêm keyframe cho part đang chọn |
# | Xóa Keyframe | `Delete` | Xóa keyframe đang chọn |
# | Copy Keyframe | `Ctrl + C` | Copy keyframe |
# | Paste Keyframe | `Ctrl + V` | Paste tại Playhead |
# | Duplicate Keyframe | `Ctrl + D` | Nhân đôi keyframe |
# | Select All | `Ctrl + A` | Chọn tất cả keyframes |
#
# ### Minh họa thêm Keyframe
#
# ```
# ┌─────────────────────────────────────────────────────────────────────────┐
# │  Timeline trước khi thêm keyframe:                                      │
# │                                                                         │
# │  RightUpperArm │  ●─────────────────────────────────────●               │
# │                   0s                                    1s              │
# │                                                                         │
# │  ─────────────────────────────────────────────────────────────────────  │
# │                                                                         │
# │  Sau khi di chuyển Playhead đến 0.5s và rotate tay:                     │
# │                                                                         │
# │  RightUpperArm │  ●──────────────●──────────────────────●               │
# │                   0s            0.5s                    1s              │
# │                                  ▲                                      │
# │                                  │                                      │
# │                           Keyframe mới!                                 │
# │                                                                         │
# └─────────────────────────────────────────────────────────────────────────┘
# ```

# %% [markdown]
# ## 1.5 Rotate và Move Body Parts
#
# ### Công cụ Transform
#
# Khi chọn một body part trong Viewport, bạn sẽ thấy các handles để transform:
#
# ```
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                    TRANSFORM TOOLS                                       │
# ├─────────────────────────────────────────────────────────────────────────┤
# │                                                                         │
# │  ROTATE TOOL (R) - Sử dụng chủ yếu trong Animation                      │
# │  ───────────────────────────────────────────                            │
# │                                                                         │
# │           ╭──────╮                                                      │
# │          ╱        ╲    ← Vòng tròn màu đỏ (X-axis rotation)             │
# │         │    ◉    │    ← Vòng tròn màu xanh lá (Y-axis rotation)        │
# │          ╲        ╱    ← Vòng tròn màu xanh dương (Z-axis rotation)     │
# │           ╰──────╯                                                      │
# │                                                                         │
# │  Cách dùng:                                                             │
# │  - Drag vòng tròn để xoay theo trục đó                                  │
# │  - Hold Shift để snap góc 15°                                           │
# │                                                                         │
# │  ─────────────────────────────────────────────────────────────────────  │
# │                                                                         │
# │  MOVE TOOL (T) - Ít dùng trong Animation                                │
# │  ───────────────────────────────────────                                │
# │                                                                         │
# │              ▲ (Y)                                                      │
# │              │                                                          │
# │              │                                                          │
# │              ◉──────► (X)                                               │
# │             ╱                                                           │
# │            ╱ (Z)                                                        │
# │                                                                         │
# │  ⚠️ Cẩn thận: Move có thể phá vỡ rig nếu dùng sai!                      │
# │                                                                         │
# └─────────────────────────────────────────────────────────────────────────┘
# ```
#
# ### Phím tắt Transform
#
# | Phím | Công cụ | Mô tả |
# |------|---------|-------|
# | `R` | Rotate | Xoay body part (dùng nhiều nhất) |
# | `T` | Move | Di chuyển body part (cẩn thận) |
# | `Shift` | Snap | Giữ để snap góc 15° |
# | `Ctrl + Z` | Undo | Hoàn tác thao tác |
# | `Ctrl + Y` | Redo | Làm lại thao tác |
#
# ### Quy tắc Rotate và Move
#
# ```
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                    QUY TẮC VÀNG                                          │
# ├─────────────────────────────────────────────────────────────────────────┤
# │                                                                         │
# │  ✅ NÊN ROTATE:                                                         │
# │  ├── Arms (xoay cánh tay)                                               │
# │  ├── Legs (xoay chân)                                                   │
# │  ├── Head (gật đầu, lắc đầu)                                            │
# │  ├── Torso (nghiêng người, xoay hông)                                   │
# │  └── Hands/Feet (xoay bàn tay/chân)                                     │
# │                                                                         │
# │  ⚠️ CẨN THẬN KHI MOVE:                                                  │
# │  ├── Move có thể khiến body parts tách rời                              │
# │  ├── Chỉ dùng move cho HumanoidRootPart (root motion)                   │
# │  └── Hoặc cho các hiệu ứng đặc biệt (stretch, squash)                   │
# │                                                                         │
# │  ❌ KHÔNG NÊN:                                                          │
# │  ├── Move body parts thông thường                                       │
# │  ├── Xoay quá 180° trong 1 frame (sẽ glitch)                            │
# │  └── Animate HumanoidRootPart nếu không cần thiết                       │
# │                                                                         │
# └─────────────────────────────────────────────────────────────────────────┘
# ```
#
# ### Ví dụ: Tạo pose giơ tay
#
# ```
# ┌─────────────────────────────────────────────────────────────────────────┐
# │  VÍ DỤ: Pose giơ tay phải lên                                           │
# ├─────────────────────────────────────────────────────────────────────────┤
# │                                                                         │
# │  1. Chọn RightUpperArm                                                  │
# │     └── Rotate Z-axis: -90° (xoay tay ra ngang)                         │
# │                                                                         │
# │  2. Chọn RightLowerArm                                                  │
# │     └── Rotate Z-axis: -45° (gập khuỷu tay)                             │
# │                                                                         │
# │  3. Chọn RightHand                                                      │
# │     └── Rotate để bàn tay hướng lên                                     │
# │                                                                         │
# │  Kết quả:                                                               │
# │                                                                         │
# │       TRƯỚC            SAU                                              │
# │         ┌─┐            ┌─┐                                              │
# │         │ │            │ │     ╱                                        │
# │       ┌─┴─┴─┐        ┌─┴─┴─╲──╱                                         │
# │       │     │        │      ╲                                           │
# │       │     │        │       │                                          │
# │      ╱│     │╲      ╱│       │╲                                         │
# │     ╱ │     │ ╲    ╱ │       │ ╲                                        │
# │    ╱  └──┬──┘  ╲  ╱  └──┬────┘  ╲                                       │
# │   ╱      │      ╲╱      │        ╲                                      │
# │                                                                         │
# └─────────────────────────────────────────────────────────────────────────┘
# ```

# %% [markdown]
# ## 1.6 Sử dụng Timeline
#
# ### Các thao tác trên Timeline
#
# ```
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                    TIMELINE OPERATIONS                                   │
# ├─────────────────────────────────────────────────────────────────────────┤
# │                                                                         │
# │  DI CHUYỂN PLAYHEAD                                                     │
# │  ────────────────────                                                   │
# │  • Click vào Timeline để nhảy đến thời điểm đó                          │
# │  • Drag Playhead (vạch đỏ) để scrub qua animation                       │
# │  • Dùng phím ← → để di chuyển từng frame                                │
# │                                                                         │
# │  ZOOM TIMELINE                                                          │
# │  ──────────────                                                         │
# │  • Scroll wheel để zoom in/out                                          │
# │  • Zoom in để chỉnh sửa chi tiết                                        │
# │  • Zoom out để xem tổng thể animation                                   │
# │                                                                         │
# │  DI CHUYỂN KEYFRAMES                                                    │
# │  ────────────────────                                                   │
# │  • Drag keyframe sang trái/phải để thay đổi timing                      │
# │  • Hold Shift + Drag để snap vào frame                                  │
# │  • Chọn nhiều keyframes và drag cùng lúc                                │
# │                                                                         │
# │  THAY ĐỔI ANIMATION LENGTH                                              │
# │  ────────────────────────────                                           │
# │  • Menu (⋮) → Settings → Set Animation Length                           │
# │  • Hoặc drag keyframe cuối cùng                                         │
# │                                                                         │
# └─────────────────────────────────────────────────────────────────────────┘
# ```
#
# ### Phím tắt Timeline
#
# | Phím | Chức năng |
# |------|-----------|
# | `Space` | Play/Pause animation |
# | `←` | Lùi 1 frame |
# | `→` | Tiến 1 frame |
# | `Home` | Về đầu animation |
# | `End` | Đến cuối animation |
# | `Scroll` | Zoom Timeline |
#
# ### Expand/Collapse Tracks
#
# ```
# ┌─────────────────────────────────────────────────────────────────────────┐
# │  TRACK LIST có thể Expand để xem chi tiết:                              │
# │                                                                         │
# │  ► LowerTorso                    (Collapsed - chỉ thấy tổng quan)       │
# │                                                                         │
# │  ▼ UpperTorso                    (Expanded - thấy chi tiết)             │
# │    ├── Position                                                         │
# │    │   ├── X                                                            │
# │    │   ├── Y                                                            │
# │    │   └── Z                                                            │
# │    └── Rotation                                                         │
# │        ├── X                                                            │
# │        ├── Y                                                            │
# │        └── Z                                                            │
# │                                                                         │
# │  Click ► để expand, ▼ để collapse                                       │
# └─────────────────────────────────────────────────────────────────────────┘
# ```

# %% [markdown]
# ## 1.7 Play/Preview Animation
#
# ### Các cách Preview Animation
#
# ```
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                    PREVIEW ANIMATION                                     │
# ├─────────────────────────────────────────────────────────────────────────┤
# │                                                                         │
# │  CÁCH 1: PLAY BUTTON                                                    │
# │  ┌─────────────────────────────────────────────────────────────────┐    │
# │  │  ◄  │  ►  │  ⏸  │  Animation Name  │  0:00 / 1:00              │    │
# │  └─────────────────────────────────────────────────────────────────┘    │
# │          ▲                                                              │
# │          │                                                              │
# │     Click Play                                                          │
# │                                                                         │
# │  CÁCH 2: PHÍM TẮT                                                       │
# │  • Space: Play/Pause                                                    │
# │                                                                         │
# │  CÁCH 3: SCRUB                                                          │
# │  • Drag Playhead qua Timeline để xem từng frame                         │
# │                                                                         │
# └─────────────────────────────────────────────────────────────────────────┘
# ```
#
# ### Preview Controls
#
# | Button | Chức năng |
# |--------|-----------|
# | ◄ (Previous) | Về keyframe trước |
# | ► (Play) | Phát animation |
# | ⏸ (Pause) | Tạm dừng |
# | ► (Next) | Đến keyframe tiếp theo |
#
# ### Looping khi Preview
#
# ```
# ┌─────────────────────────────────────────────────────────────────────────┐
# │  Khi Preview, animation sẽ loop liên tục.                               │
# │                                                                         │
# │  Để thay đổi Looping:                                                   │
# │  Menu (⋮) → Settings → Looping                                          │
# │                                                                         │
# │  ○ Looping: ON  → Animation lặp vô hạn                                  │
# │  ○ Looping: OFF → Animation chỉ phát 1 lần                              │
# │                                                                         │
# │  ⚠️ Setting này sẽ được lưu khi Publish!                                │
# └─────────────────────────────────────────────────────────────────────────┘
# ```
#
# ### Tips khi Preview
#
# ✅ **Nên làm:**
# - Preview thường xuyên sau mỗi vài keyframes
# - Xem ở nhiều góc độ (xoay camera)
# - Scrub chậm để kiểm tra từng frame
# - Test cả loop và không loop
#
# ❌ **Tránh:**
# - Không preview và chỉ dựa vào keyframes
# - Quên kiểm tra transition giữa các poses

# %% [markdown]
# ## 1.8 Easing Styles
#
# ### Easing là gì?
# **Easing** quyết định **cách** animation chuyển động giữa 2 keyframes. Thay vì di chuyển đều (linear), bạn có thể làm cho chuyển động tự nhiên hơn với các easing styles khác nhau.
#
# ### Các Easing Styles trong Roblox
#
# ```
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                    EASING STYLES                                         │
# ├─────────────────────────────────────────────────────────────────────────┤
# │                                                                         │
# │  LINEAR                                                                 │
# │  ═══════                                                                │
# │  ┌────────────────────────┐                                             │
# │  │        ╱               │  Tốc độ đều từ đầu đến cuối                 │
# │  │      ╱                 │  Dùng cho: Robot, máy móc                   │
# │  │    ╱                   │                                             │
# │  │  ╱                     │                                             │
# │  └────────────────────────┘                                             │
# │                                                                         │
# │  CUBIC (Ease In/Out/InOut)                                              │
# │  ═════════════════════════                                              │
# │  ┌────────────────────────┐                                             │
# │  │           ___─────     │  Ease In: Bắt đầu chậm, tăng tốc           │
# │  │        ╱               │  Ease Out: Bắt đầu nhanh, giảm tốc          │
# │  │  ─────                 │  Ease InOut: Chậm-Nhanh-Chậm                │
# │  └────────────────────────┘                                             │
# │                                                                         │
# │  BOUNCE                                                                 │
# │  ══════                                                                 │
# │  ┌────────────────────────┐                                             │
# │  │         ∿∿∿───         │  Nảy lên khi kết thúc                       │
# │  │        ╱               │  Dùng cho: Nhảy, landing, ball              │
# │  │      ╱                 │                                             │
# │  └────────────────────────┘                                             │
# │                                                                         │
# │  ELASTIC                                                                │
# │  ════════                                                               │
# │  ┌────────────────────────┐                                             │
# │  │      ∿∿─────           │  Dao động như dây cao su                    │
# │  │     ╱                  │  Dùng cho: Hoạt hình vui nhộn               │
# │  │   ╱                    │                                             │
# │  └────────────────────────┘                                             │
# │                                                                         │
# │  CONSTANT                                                               │
# │  ═════════                                                              │
# │  ┌────────────────────────┐                                             │
# │  │                   ┌────│  Nhảy ngay lập tức                          │
# │  │                   │    │  Không có transition                        │
# │  │───────────────────┘    │  Dùng cho: Instant effects                  │
# │  └────────────────────────┘                                             │
# │                                                                         │
# └─────────────────────────────────────────────────────────────────────────┘
# ```
#
# ### Cách thay đổi Easing
#
# ```
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                    THAY ĐỔI EASING                                       │
# ├─────────────────────────────────────────────────────────────────────────┤
# │                                                                         │
# │  1. Right-click vào keyframe trên Timeline                              │
# │  2. Chọn "Easing Style"                                                 │
# │  3. Chọn một trong các options:                                         │
# │                                                                         │
# │     ┌─────────────────────────────────────┐                             │
# │     │  Easing Style          ►           │                             │
# │     ├─────────────────────────────────────┤                             │
# │     │  ○ Linear                           │                             │
# │     │  ○ Constant                         │                             │
# │     │  ○ Cubic                            │                             │
# │     │  ○ Elastic                          │                             │
# │     │  ○ Bounce                           │                             │
# │     └─────────────────────────────────────┘                             │
# │                                                                         │
# │  4. Chọn "Easing Direction":                                            │
# │     ○ In     (bắt đầu chậm)                                             │
# │     ○ Out    (kết thúc chậm)                                            │
# │     ○ InOut  (cả hai)                                                   │
# │                                                                         │
# └─────────────────────────────────────────────────────────────────────────┘
# ```
#
# ### Bảng chọn Easing theo loại Animation
#
# | Animation | Easing Style | Direction | Lý do |
# |-----------|--------------|-----------|-------|
# | **Attack Swing** | Cubic | Out | Nhanh rồi chậm lại |
# | **Attack Prepare** | Cubic | In | Chậm rồi nhanh dần |
# | **Walk/Run** | Linear | - | Đều đặn, lặp lại |
# | **Jump Up** | Cubic | Out | Bắn lên nhanh, chậm dần |
# | **Landing** | Bounce | Out | Chạm đất, nảy nhẹ |
# | **Idle Breathing** | Cubic | InOut | Tự nhiên, mượt mà |
# | **Emote Dance** | Elastic | Out | Vui nhộn, năng động |
# | **Teleport** | Constant | - | Instant, không transition |
#
# ### Ví dụ thực tế: Sword Slash
#
# ```
# ┌─────────────────────────────────────────────────────────────────────────┐
# │  SWORD SLASH ANIMATION TIMING                                           │
# ├─────────────────────────────────────────────────────────────────────────┤
# │                                                                         │
# │  Keyframe 1 (0.00s): Idle stance                                        │
# │       ↓                                                                 │
# │       │ Easing: Cubic In (chậm → nhanh, chuẩn bị chém)                  │
# │       ↓                                                                 │
# │  Keyframe 2 (0.15s): Wind up (giơ kiếm lên)                             │
# │       ↓                                                                 │
# │       │ Easing: Cubic Out (nhanh → chậm, chém xuống mạnh)               │
# │       ↓                                                                 │
# │  Keyframe 3 (0.25s): Slash (chém qua)                                   │
# │       ↓                                                                 │
# │       │ Easing: Cubic InOut (recovery mượt mà)                          │
# │       ↓                                                                 │
# │  Keyframe 4 (0.40s): Recovery (về stance)                               │
# │                                                                         │
# └─────────────────────────────────────────────────────────────────────────┘
# ```

# %% [markdown]
# ---
#
# # 📤 PHẦN 2: PUBLISH ANIMATION
#
# ---

# %% [markdown]
# ## 2.1 Save Animation Locally
#
# ### Tại sao cần Save Locally?
# - Backup animation trước khi publish
# - Có thể edit lại sau này
# - Chia sẻ file animation với team members
#
# ### Cách Save Animation Locally
#
# ```
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                    SAVE ANIMATION LOCALLY                                │
# ├─────────────────────────────────────────────────────────────────────────┤
# │                                                                         │
# │  CÁCH 1: Save trong Animation Editor                                    │
# │  ────────────────────────────────────                                   │
# │  1. Menu (⋮) → "Save" hoặc "Save As"                                    │
# │  2. Animation được lưu trong Rig model                                  │
# │                                                                         │
# │  CÁCH 2: Export Animation                                               │
# │  ───────────────────────────                                            │
# │  1. Menu (⋮) → "Export"                                                 │
# │  2. Chọn định dạng:                                                     │
# │     • .rbxm (Roblox Model - chứa KeyframeSequence)                      │
# │     • .rbxmx (Roblox Model XML - dễ đọc hơn)                            │
# │  3. Chọn nơi lưu file                                                   │
# │                                                                         │
# │  ─────────────────────────────────────────────────────────────────────  │
# │                                                                         │
# │  Animation được lưu ở đâu trong Explorer?                               │
# │                                                                         │
# │  Rig (Model)                                                            │
# │  └── AnimSaves (Folder)                                                 │
# │      ├── Walk (KeyframeSequence)     ◄── Animation đã save              │
# │      ├── Run (KeyframeSequence)                                         │
# │      └── Attack1 (KeyframeSequence)                                     │
# │                                                                         │
# └─────────────────────────────────────────────────────────────────────────┘
# ```
#
# ### KeyframeSequence là gì?
#
# ```lua
# -- KeyframeSequence chứa tất cả keyframes của animation
# -- Cấu trúc trong Explorer:
#
# KeyframeSequence ("Walk")
# ├── Keyframe (Time = 0)
# │   └── Pose ("LowerTorso")
# │       ├── CFrame = ...
# │       └── Pose ("UpperTorso")
# │           └── Pose ("Head")
# │           └── Pose ("LeftUpperArm")
# │           └── ...
# ├── Keyframe (Time = 0.5)
# │   └── ...
# └── Keyframe (Time = 1.0)
#     └── ...
# ```

# %% [markdown]
# ## 2.2 Publish to Roblox
#
# ### Tại sao cần Publish?
# - Để có **Animation ID** dùng trong script
# - Animation được lưu trên cloud của Roblox
# - Có thể dùng animation trong bất kỳ game nào của bạn
#
# ### Cách Publish Animation
#
# ```
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                    PUBLISH ANIMATION                                     │
# ├─────────────────────────────────────────────────────────────────────────┤
# │                                                                         │
# │  BƯỚC 1: Hoàn thành animation                                           │
# │          └── Đảm bảo animation đã hoàn chỉnh và test kỹ                 │
# │                                                                         │
# │  BƯỚC 2: Mở menu Publish                                                │
# │          └── Menu (⋮) → "Publish to Roblox"                             │
# │                                                                         │
# │  BƯỚC 3: Chọn nơi Publish                                               │
# │          ┌─────────────────────────────────────────────────────────┐    │
# │          │           PUBLISH ANIMATION                             │    │
# │          ├─────────────────────────────────────────────────────────┤    │
# │          │                                                         │    │
# │          │  Animation Name: [Walk________________]                 │    │
# │          │                                                         │    │
# │          │  Publish To:                                            │    │
# │          │  ○ Me (Đăng dưới tên cá nhân)                           │    │
# │          │  ○ Group: [Select Group ▼]                              │    │
# │          │                                                         │    │
# │          │  Description: [Optional description__]                  │    │
# │          │                                                         │    │
# │          │           [ Submit ]  [ Cancel ]                        │    │
# │          └─────────────────────────────────────────────────────────┘    │
# │                                                                         │
# │  BƯỚC 4: Click "Submit"                                                 │
# │          └── Đợi upload hoàn tất                                        │
# │                                                                         │
# │  BƯỚC 5: Copy Animation ID                                              │
# │          └── Popup hiện ID, copy để dùng trong script                   │
# │                                                                         │
# └─────────────────────────────────────────────────────────────────────────┘
# ```
#
# ### Publish to Me vs Group
#
# | Publish To | Ownership | Ai có thể dùng? |
# |------------|-----------|------------------|
# | **Me** | Cá nhân | Chỉ trong games của bạn |
# | **Group** | Group | Games thuộc group đó |
#
# > ⚠️ **Quan trọng:** Nếu game của bạn thuộc Group, phải publish animation to **Group** để animation hoạt động!

# %% [markdown]
# ## 2.3 Lấy Animation ID
#
# ### Animation ID là gì?
# **Animation ID** là mã số định danh duy nhất của animation trên Roblox. Định dạng: `rbxassetid://123456789`
#
# ### Cách lấy Animation ID
#
# ```
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                    LẤY ANIMATION ID                                      │
# ├─────────────────────────────────────────────────────────────────────────┤
# │                                                                         │
# │  CÁCH 1: SAU KHI PUBLISH                                                │
# │  ────────────────────────                                               │
# │  • Popup tự động hiện Animation ID sau khi publish                      │
# │  • Copy ID ngay lập tức                                                 │
# │                                                                         │
# │  CÁCH 2: TỪ ROBLOX WEBSITE                                              │
# │  ───────────────────────                                                │
# │  1. Đăng nhập Roblox.com                                                │
# │  2. Vào Create (https://create.roblox.com)                              │
# │  3. Development Items → Animations                                      │
# │  4. Click vào animation                                                 │
# │  5. Copy ID từ URL hoặc trang chi tiết                                  │
# │                                                                         │
# │  URL: https://www.roblox.com/library/123456789/AnimationName            │
# │                                    ▲                                    │
# │                                    │                                    │
# │                               Đây là ID!                                │
# │                                                                         │
# │  CÁCH 3: TỪ ANIMATION EDITOR                                            │
# │  ────────────────────────────                                           │
# │  • Menu (⋮) → Animation Properties                                      │
# │  • Xem "Asset ID" nếu đã publish                                        │
# │                                                                         │
# └─────────────────────────────────────────────────────────────────────────┘
# ```
#
# ### Sử dụng Animation ID trong Script
#
# ```lua
# -- Cách sử dụng Animation ID
#
# local animation = Instance.new("Animation")
#
# -- Format đúng:
# animation.AnimationId = "rbxassetid://123456789"
#
# -- KHÔNG dùng URL đầy đủ:
# -- animation.AnimationId = "https://www.roblox.com/library/123456789"  ❌
#
# -- Load và phát
# local animator = humanoid:WaitForChild("Animator")
# local track = animator:LoadAnimation(animation)
# track:Play()
# ```
#
# ### Lưu trữ Animation IDs
#
# ```lua
# -- Nên tạo module để lưu trữ tất cả Animation IDs
#
# -- AnimationIDs.lua (ModuleScript)
# local AnimationIDs = {
#     -- Movement
#     Walk = "rbxassetid://111111111",
#     Run = "rbxassetid://222222222",
#     Jump = "rbxassetid://333333333",
#
#     -- Combat
#     Attack1 = "rbxassetid://444444444",
#     Attack2 = "rbxassetid://555555555",
#     Block = "rbxassetid://666666666",
#
#     -- Emotes
#     Wave = "rbxassetid://777777777",
#     Dance = "rbxassetid://888888888",
# }
#
# return AnimationIDs
# ```

# %% [markdown]
# ## 2.4 Hiểu về Animation Ownership
#
# ### Animation Ownership là gì?
# **Ownership** (quyền sở hữu) quyết định ai có thể sử dụng animation trong game của họ.
#
# ### Quy tắc Ownership
#
# ```
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                    ANIMATION OWNERSHIP RULES                             │
# ├─────────────────────────────────────────────────────────────────────────┤
# │                                                                         │
# │  QUY TẮC 1: GAME CỦA CÁ NHÂN                                            │
# │  ────────────────────────────                                           │
# │  • Game owner = Your account                                            │
# │  • Animation owner = Your account                                       │
# │  • → Animation hoạt động ✅                                             │
# │                                                                         │
# │  QUY TẮC 2: GAME CỦA GROUP                                              │
# │  ───────────────────────────                                            │
# │  • Game owner = Group                                                   │
# │  • Animation owner = Phải là Group                                      │
# │  • → Animation publish to Group mới hoạt động ✅                        │
# │                                                                         │
# │  ❌ KHÔNG HOẠT ĐỘNG:                                                    │
# │  • Game của Group + Animation của cá nhân = LỖI                         │
# │  • Game của bạn + Animation của người khác = LỖI                        │
# │                                                                         │
# └─────────────────────────────────────────────────────────────────────────┘
# ```
#
# ### Bảng tổng hợp Ownership
#
# | Game Owner | Animation Owner | Hoạt động? |
# |------------|-----------------|------------|
# | You | You | ✅ Có |
# | Your Group | Your Group | ✅ Có |
# | Your Group | You | ❌ Không |
# | You | Your Group | ❌ Không |
# | You | Người khác | ❌ Không |
#
# ### Lỗi thường gặp
#
# ```
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                    LỖI THƯỜNG GẶP VÀ CÁCH KHẮC PHỤC                      │
# ├─────────────────────────────────────────────────────────────────────────┤
# │                                                                         │
# │  LỖI: Animation không phát trong game                                   │
# │                                                                         │
# │  NGUYÊN NHÂN:                                                           │
# │  1. Ownership không khớp (game group ≠ animation owner)                 │
# │  2. Animation ID sai                                                    │
# │  3. Animation bị moderated/deleted                                      │
# │  4. Animation chưa publish                                              │
# │                                                                         │
# │  CÁCH KIỂM TRA:                                                         │
# │  • Xem Output console có lỗi không                                      │
# │  • Verify animation tồn tại trên website                                │
# │  • Kiểm tra game owner và animation owner                               │
# │                                                                         │
# │  CÁCH KHẮC PHỤC:                                                        │
# │  • Re-publish animation đến đúng owner (group/me)                       │
# │  • Copy lại Animation ID mới                                            │
# │                                                                         │
# └─────────────────────────────────────────────────────────────────────────┘
# ```
#
# ### Chia sẻ Animation với Team
#
# ```
# ┌─────────────────────────────────────────────────────────────────────────┐
# │  BEST PRACTICE KHI LÀM VIỆC NHÓM                                        │
# ├─────────────────────────────────────────────────────────────────────────┤
# │                                                                         │
# │  1. Tạo Group cho team phát triển game                                  │
# │                                                                         │
# │  2. Game thuộc về Group                                                 │
# │                                                                         │
# │  3. TẤT CẢ animations phải publish to Group                             │
# │                                                                         │
# │  4. Người tạo animation cần có quyền trong Group:                       │
# │     • Configure Group (hoặc cao hơn)                                    │
# │     • Để có thể publish to Group                                        │
# │                                                                         │
# │  5. Lưu Animation IDs trong shared document/code                        │
# │                                                                         │
# └─────────────────────────────────────────────────────────────────────────┘
# ```

# %% [markdown]
# ---
#
# # 📝 TỔNG KẾT
#
# ---

# %% [markdown]
# ## Checklist kiến thức đã học
#
# ### Phần 1: Sử dụng Animation Editor
# - [x] Mở Animation Editor (Avatar → Animation Editor)
# - [x] Tạo Rig R15 (Avatar → Rig Builder)
# - [x] Tạo animation mới
# - [x] Thêm/xóa keyframes
# - [x] Rotate và Move body parts
# - [x] Sử dụng Timeline
# - [x] Play/Preview animation
# - [x] Easing Styles (Linear, Cubic, Bounce...)
#
# ### Phần 2: Publish Animation
# - [x] Save animation locally
# - [x] Publish to Roblox
# - [x] Lấy Animation ID
# - [x] Hiểu về animation ownership
#
# ---
#
# ## Phím tắt quan trọng
#
# | Phím | Chức năng |
# |------|-----------|
# | `Space` | Play/Pause |
# | `K` | Thêm Keyframe |
# | `Delete` | Xóa Keyframe |
# | `R` | Rotate tool |
# | `T` | Move tool |
# | `←` `→` | Di chuyển 1 frame |
# | `Ctrl + Z` | Undo |
# | `Ctrl + C/V` | Copy/Paste |
#
# ---
#
# ## Bước tiếp theo
#
# Sau khi thành thạo Animation Editor, bạn sẵn sàng để:
#
# 1. **1.4 Scripting Animation Cơ Bản** - Viết code Luau để phát animation
# 2. **1.5 Project Thực Hành** - Tạo Wave Emote, Jump Animation, Idle Variations
#
# ---
#
# ## Tài liệu tham khảo
#
# - [Animation Editor Documentation](https://create.roblox.com/docs/animation/editor)
# - [Rig Builder Guide](https://create.roblox.com/docs/art/characters/rig-builder)
# - [Using Animations](https://create.roblox.com/docs/animation/using)
